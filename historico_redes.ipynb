# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score
# ----------------------------------------------------------------------------------------------------------------------------------------
# CARGA DEL CONJUNTO DE ENTRENAMIENTO
f = open('train-images.idx3-ubyte', 'rb')
# Descartar cabecera (16 bytes)
f.read(16)
# El resto de datos son las imágenes.
# La intensidad en escala de grises para cada píxel se guarda en un byte
# Las imágenes son de 28 * 28 por lo que ocupan 784 bytes adyacentes
images_train = []
while True:
    # Leemos la siguiente imagen
    image = f.read(784)
    if len(image) != 784: # Si no queda imagen parar
        break
    else: # Conversión de binario a entero
        images_train.append([x for x in image])

# Conversión a array de NumPy
images_train = np.array(images_train)
# Muestra por pantalla el primer número para comprobar
#plt.imshow(images[0].reshape(28,28), cmap='gray')
# Lectura de etiquetas
f = open('train-labels.idx1-ubyte', 'rb')
# Descartar cabecera (8 bytes)
f.read(8)
# El resto de datos son las etiquetas. Cada etiqueta es un byte
etiquetas_train = np.array([x for x in f.read()])
#print(etiquetas)
# ----------------------------------------------------------------------------------------------------------------------------------------
# INCREMENTO DEL CONJUNTO DE ENTRENAMIENTO
#datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=15, width_shift_range=0.1, height_shift_range=0.1, zoom_range=0.2)
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=15)
it = datagen.flow(images_train.reshape((-1,28,28,1)), etiquetas_train, batch_size=1)
nuevas_imagenes = [it [i][0] for i in range(60000)]
nuevas_etiquetas = [it [i][1] for i in range(60000)]
fullImagenes= np.concatenate([images_train, np.array(nuevas_imagenes).reshape((60000, 28*28))])
fullEtiquetas= np.concatenate([etiquetas_train, np.array(nuevas_etiquetas).reshape(60000,)])
# ----------------------------------------------------------------------------------------------------------------------------------------
# CARGA DEL CONJUNTO DE TEST
f = open('t10k-images.idx3-ubyte', 'rb')
# Descartar cabecera (16 bytes)
f.read(16)
# El resto de datos son las imágenes.
# La intensidad en escala de grises para cada píxel se guarda en un byte
# Las imágenes son de 28 * 28 por lo que ocupan 784 bytes adyacentes
images_test = []
while True:
    # Leemos la siguiente imagen
    image = f.read(784)
    if len(image) != 784: # Si no queda imagen parar
        break
    else: # Conversión de binario a entero
        images_test.append([x for x in image])
# Conversión a array de NumPy
images_test = np.array(images_test)
# Muestra por pantalla el primer número para comprobar
#plt.imshow(images[0].reshape(28,28), cmap='gray')
# Lectura de etiquetas
f = open('t10k-labels.idx1-ubyte', 'rb')
# Descartar cabecera (8 bytes)
f.read(8)
# El resto de datos son las etiquetas. Cada etiqueta es un byte
etiquetas_test = np.array([x for x in f.read()])
# Out:
# 2024-12-08 19:15:40.064945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733681740.094068    9082 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733681740.102031    9082 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-08 19:15:40.133196: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#RED 1: Completamente conectada | 1 CAPA
model_red_1 = tf.keras.models.Sequential()
model_red_1.add(tf.keras.layers.Dense(512, activation='sigmoid'))
model_red_1.add(tf.keras.layers.Dense(10, activation='softmax'))
#Para entrenar el modelo
#tf.keras.optimizers.Adam(learning_rate=0.0015)
model_red_1.compile('adam', 'categorical_crossentropy') #funcion de perdida
etiquetas_red_1 = tf.keras.utils.to_categorical(etiquetas_train)
model_red_1.fit(images_train, etiquetas_red_1, epochs=100)

preds_train_red_1 = model_red_1.predict(images_train).argmax(axis=1)
acc_train = accuracy_score(etiquetas_red_1.argmax(axis=1),preds_train_red_1)
print("----------------------ENTRENAMIENTO---------------------------------")
print("Precisión: ", acc_train, "Tasa de error: ", 1 - acc_train)
preds_test_red_1 = model_red_1.predict(images_test).argmax(axis=1)
acc_test = accuracy_score(etiquetas_test, preds_test_red_1)
print("----------------------PRUEBA---------------------------------")
print("Precisión: ", acc_test, "Tasa de error: ", 1 - acc_test)
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.5661
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2958
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2622
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2449
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.2249
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.2114
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.2021
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2089
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1979
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1864
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1959
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1889
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1775
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1748
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1789
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1626
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1656
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1694
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1520
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1560
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1518
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1537
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1570
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1529
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1511
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1458
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1390
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1476
# Epoch 29/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1432
# Epoch 30/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1445
# Epoch 31/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1332
# Epoch 32/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1339
# Epoch 33/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1331
# Epoch 34/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1349
# Epoch 35/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1415
# Epoch 36/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1306
# Epoch 37/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1323
# Epoch 38/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1324
# Epoch 39/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1322
# Epoch 40/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1298
# Epoch 41/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1260
# Epoch 42/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1354
# Epoch 43/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1365
# Epoch 44/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1313
# Epoch 45/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1227
# Epoch 46/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1196
# Epoch 47/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1245
# Epoch 48/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1283
# Epoch 49/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1300
# Epoch 50/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1317
# Epoch 51/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1202
# Epoch 52/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1185
# Epoch 53/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1166
# Epoch 54/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1159
# Epoch 55/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1177
# Epoch 56/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1155
# Epoch 57/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1232
# Epoch 58/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1164
# Epoch 59/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1126
# Epoch 60/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1152
# Epoch 61/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1115
# Epoch 62/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1105
# Epoch 63/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1149
# Epoch 64/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1185
# Epoch 65/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1109
# Epoch 66/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1161
# Epoch 67/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1076
# Epoch 68/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1122
# Epoch 69/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1108
# Epoch 70/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1087
# Epoch 71/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1127
# Epoch 72/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1017
# Epoch 73/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1087
# Epoch 74/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0983
# Epoch 75/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1053
# Epoch 76/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1034
# Epoch 77/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1076
# Epoch 78/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1138
# Epoch 79/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1057
# Epoch 80/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1044
# Epoch 81/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1074
# Epoch 82/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1036
# Epoch 83/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1010
# Epoch 84/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0963
# Epoch 85/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1019
# Epoch 86/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1004
# Epoch 87/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1012
# Epoch 88/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1019
# Epoch 89/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0938
# Epoch 90/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0915
# Epoch 91/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1002
# Epoch 92/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0949
# Epoch 93/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1018
# Epoch 94/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0967
# Epoch 95/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0977
# Epoch 96/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0970
# Epoch 97/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0984
# Epoch 98/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0958
# Epoch 99/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0952
# Epoch 100/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0957
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# ----------------------ENTRENAMIENTO---------------------------------
# Precisión:  0.9706833333333333 Tasa de error:  0.029316666666666658
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ----------------------PRUEBA---------------------------------
# Precisión:  0.9651 Tasa de error:  0.03490000000000004

# %%
#RED 2: Completamente conectada | 3 CAPAS
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', verbose=1, patience=15)
model_red_2 = tf.keras.models.Sequential()
#model_red_2.add(tf.keras.layers.Dense(512, activation='sigmoid'))
model_red_2.add(tf.keras.layers.Dense(256, activation='sigmoid'))
model_red_2.add(tf.keras.layers.Dense(128, activation='sigmoid'))
model_red_2.add(tf.keras.layers.Dense(64, activation='sigmoid'))
model_red_2.add(tf.keras.layers.Dense(10, activation='softmax'))
#Para entrenar el modelo
#tf.keras.optimizers.Adam(learning_rate=0.0015)
#model_red_2.compile('adam', 'categorical_crossentropy') #funcion de perdida
model_red_2.compile('adamW', 'categorical_crossentropy') #funcion de perdida
etiquetas_red_2 = tf.keras.utils.to_categorical(etiquetas_train)
model_red_2.fit(images_train, etiquetas_red_2, epochs=100, callbacks=[early_stopping])
#model_red_2.fit(images_train, etiquetas_red_2, epochs=100)

preds_train_red_2 = model_red_2.predict(images_train).argmax(axis=1)
acc_train = accuracy_score(etiquetas_red_2.argmax(axis=1),preds_train_red_2)
print("----------------------ENTRENAMIENTO---------------------------------")
print("Precisión: ", acc_train, "Tasa de error: ", 1 - acc_train)
preds_test_red_2 = model_red_2.predict(images_test).argmax(axis=1)
acc_test = accuracy_score(etiquetas_test, preds_test_red_2)
print("----------------------PRUEBA---------------------------------")
print("Precisión: ", acc_test, "Tasa de error: ", 1 - acc_test)
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 969us/step - loss: 0.9327
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 956us/step - loss: 0.3468
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 931us/step - loss: 0.2912
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.2823
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.2547
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.2284
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 933us/step - loss: 0.2196
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.2115
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1956
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1869
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1814
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1785
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1701
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1523
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1479
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 948us/step - loss: 0.1544
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 948us/step - loss: 0.1558
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 964us/step - loss: 0.1419
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 957us/step - loss: 0.1386
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 977us/step - loss: 0.1352
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 957us/step - loss: 0.1393
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 931us/step - loss: 0.1321
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 975us/step - loss: 0.1275
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 975us/step - loss: 0.1274
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 959us/step - loss: 0.1237
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1236
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 968us/step - loss: 0.1251
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1205
# Epoch 29/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1197
# Epoch 30/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 948us/step - loss: 0.1218
# Epoch 31/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 941us/step - loss: 0.1121
# Epoch 32/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 935us/step - loss: 0.1215
# Epoch 33/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 979us/step - loss: 0.1077
# Epoch 34/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1074
# Epoch 35/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.1084
# Epoch 36/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1104
# Epoch 37/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 987us/step - loss: 0.1056
# Epoch 38/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1021
# Epoch 39/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 990us/step - loss: 0.1018
# Epoch 40/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0939
# Epoch 41/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 961us/step - loss: 0.0978
# Epoch 42/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 969us/step - loss: 0.0957
# Epoch 43/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0957
# Epoch 44/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 983us/step - loss: 0.0969
# Epoch 45/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 999us/step - loss: 0.0932
# Epoch 46/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 960us/step - loss: 0.0956
# Epoch 47/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 946us/step - loss: 0.0948
# Epoch 48/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 995us/step - loss: 0.0977
# Epoch 49/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0936
# Epoch 50/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0900
# Epoch 51/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0918
# Epoch 52/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0885
# Epoch 53/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0902
# Epoch 54/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0859
# Epoch 55/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0925
# Epoch 56/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0793
# Epoch 57/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0866
# Epoch 58/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0832
# Epoch 59/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0861
# Epoch 60/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0829
# Epoch 61/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0836
# Epoch 62/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0823
# Epoch 63/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0771
# Epoch 64/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0887
# Epoch 65/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0786
# Epoch 66/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0814
# Epoch 67/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0812
# Epoch 68/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0768
# Epoch 69/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0767
# Epoch 70/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0868
# Epoch 71/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0833
# Epoch 72/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0765
# Epoch 73/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0779
# Epoch 74/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0759
# Epoch 75/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0713
# Epoch 76/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0770
# Epoch 77/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0759
# Epoch 78/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0789
# Epoch 79/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0795
# Epoch 80/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0709
# Epoch 81/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0745
# Epoch 82/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0749
# Epoch 83/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0758
# Epoch 84/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0747
# Epoch 85/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0762
# Epoch 86/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0740
# Epoch 87/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0728
# Epoch 88/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0743
# Epoch 89/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0764
# Epoch 90/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0712
# Epoch 91/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0743
# Epoch 91: early stopping
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# ----------------------ENTRENAMIENTO---------------------------------
# Precisión:  0.9748833333333333 Tasa de error:  0.025116666666666676
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ----------------------PRUEBA---------------------------------
# Precisión:  0.9638 Tasa de error:  0.03620000000000001

# %%
#RED 3: CONVOLUCIONAL | 3 CAPAS
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', verbose=1, patience=15)
model_red_3 = tf.keras.models.Sequential()
model_red_3.add(tf.keras.layers.Reshape((28,28,1)))
model_red_3.add(tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'))
model_red_3.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model_red_3.add(tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'))
model_red_3.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model_red_3.add(tf.keras.layers.Flatten())
model_red_3.add(tf.keras.layers.Dense(128, activation='sigmoid'))
model_red_3.add(tf.keras.layers.Dense(64, activation='sigmoid'))
model_red_3.add(tf.keras.layers.Dense(10, activation='softmax'))
#Para entrenar el modelo
#tf.keras.optimizers.Adam(learning_rate=0.0015)
model_red_3.compile('adamW', 'categorical_crossentropy') #funcion de perdida
etiquetas_red_3 = tf.keras.utils.to_categorical(etiquetas_train)
model_red_3.fit(images_train, etiquetas_red_3, epochs=100, callbacks=[early_stopping])

preds_train_red_3 = model_red_3.predict(images_train).argmax(axis=1)
acc_train = accuracy_score(etiquetas_red_3.argmax(axis=1),preds_train_red_3)
print("----------------------ENTRENAMIENTO---------------------------------")
print("Precisión: ", acc_train, "Tasa de error: ", 1 - acc_train)
preds_test_red_3 = model_red_3.predict(images_test).argmax(axis=1)
acc_test = accuracy_score(etiquetas_test, preds_test_red_3)
print("----------------------PRUEBA---------------------------------")
print("Precisión: ", acc_test, "Tasa de error: ", 1 - acc_test)
# Out:
# Epoch 1/100
# 2024-12-08 20:44:40.417724: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[32,32,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,14,14]{3,2,1,0}, f32[32,16,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.6051
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0635
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0527
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0500
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0499
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0493
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0414
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0427
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0449
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0446
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0498
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0462
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0446
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0428
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0415
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0432
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0523
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0510
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0455
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0459
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0394
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0484
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0462
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0443
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0459
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0418
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0470
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0445
# Epoch 29/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0427
# Epoch 30/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0470
# Epoch 30: early stopping
# 2024-12-08 20:46:18.819830: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[32,32,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,14,14]{3,2,1,0}, f32[32,16,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# ----------------------ENTRENAMIENTO---------------------------------
# Precisión:  0.9871833333333333 Tasa de error:  0.012816666666666698
# 293/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2024-12-08 20:46:22.948876: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[16,32,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,16,14,14]{3,2,1,0}, f32[32,16,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# ----------------------PRUEBA---------------------------------
# Precisión:  0.984 Tasa de error:  0.016000000000000014

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=1, patience=15)
reduce_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.75, patience=4, min_lr=0.0002, verbose=1)

#Definimos la red
model_definitivo = tf.keras.models.Sequential()
#Añade una capa, las capas estan en keras.layers.Dense
#Este caso es la capa oculta
model_definitivo.add(tf.keras.layers.Reshape((28,28,1)))
model_definitivo.add(tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'))
model_definitivo.add(tf.keras.layers.BatchNormalization())
model_definitivo.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
#model_definitivo.add(tf.keras.layers.Dropout(0.5))
model_definitivo.add(tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'))
model_definitivo.add(tf.keras.layers.BatchNormalization())
model_definitivo.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model_definitivo.add(tf.keras.layers.Dropout(0.5))
model_definitivo.add(tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'))
model_definitivo.add(tf.keras.layers.BatchNormalization())
model_definitivo.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model_definitivo.add(tf.keras.layers.Flatten())
model_definitivo.add(tf.keras.layers.Dropout(0.5))
model_definitivo.add(tf.keras.layers.Dense(64, activation='relu'))
#model.add(tf.keras.layers.Dropout(0.2))
#Capa de salida
model_definitivo.add(tf.keras.layers.Dense(10, activation='softmax'))
#Para entrenar el modelo
optimizador=tf.keras.optimizers.AdamW(learning_rate=0.0015, weight_decay=0.005)
model_definitivo.compile(optimizer=optimizador, loss='categorical_crossentropy', metrics=['accuracy']) #funcion de perdida
etiquetas_definitivas = tf.keras.utils.to_categorical(fullEtiquetas)
model_definitivo.fit(fullImagenes, etiquetas_definitivas, epochs=200, callbacks=[early_stopping, reduce_on_plateau], validation_split=0.2) #Se le añade el callback personalizado
# Out:
# Epoch 1/200
# 2541/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7397 - loss: 0.8239
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 30
#      28 model_definitivo.compile(optimizer=optimizador, loss='categorical_crossentropy', metrics=['accuracy']) #funcion de perdida
#      29 etiquetas_definitivas = tf.keras.utils.to_categorical(fullEtiquetas)
# ---> 30 model_definitivo.fit(fullImagenes, etiquetas_definitivas, epochs=200, callbacks=[early_stopping, reduce_on_plateau], validation_split=0.2) #Se le añade el callback personalizado
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
preds_train_definitivo = model_definitivo.predict(fullImagenes).argmax(axis=1)
acc_train = accuracy_score(etiquetas_definitivas.argmax(axis=1), preds_train_definitivo)
print("----------------------ENTRENAMIENTO---------------------------------")
print("Precisión: ", acc_train, "Tasa de error: ", 1 - acc_train)
preds_test_definitivo = model_definitivo.predict(images_test).argmax(axis=1)
acc_test = accuracy_score(etiquetas_test, preds_test_definitivo)
print("----------------------PRUEBA---------------------------------")
print("Precisión: ", acc_test, "Tasa de error: ", 1 - acc_test)
# Out:
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step
# ----------------------ENTRENAMIENTO---------------------------------
# Precisión:  0.9595666666666667 Tasa de error:  0.04043333333333332
# 307/313 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2024-12-08 22:12:47.508800: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{} for conv (f32[16,8,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,16,3,3]{3,2,1,0}, f32[8,16,3,3]{3,2,1,0}, f32[8]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# ----------------------PRUEBA---------------------------------
# Precisión:  0.9694 Tasa de error:  0.03059999999999996

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=1, patience=15)
reduce_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.75, patience=4, min_lr=0.0002, verbose=1)

#Definimos la red
model_pruebas = tf.keras.models.Sequential()
#Añade una capa, las capas estan en keras.layers.Dense
#Este caso es la capa oculta
model_pruebas.add(tf.keras.layers.Reshape((28,28,1)))
model_pruebas.add(tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'))
model_pruebas.add(tf.keras.layers.BatchNormalization())
model_pruebas.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
#model_pruebas.add(tf.keras.layers.Dropout(0.5))
model_pruebas.add(tf.keras.layers.Conv2D(24, 3, activation='relu', padding='same'))
model_pruebas.add(tf.keras.layers.BatchNormalization())
model_pruebas.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model_pruebas.add(tf.keras.layers.Dropout(0.5))
model_pruebas.add(tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'))
model_pruebas.add(tf.keras.layers.BatchNormalization())
model_pruebas.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model_pruebas.add(tf.keras.layers.Flatten())
model_pruebas.add(tf.keras.layers.Dropout(0.5))
model_pruebas.add(tf.keras.layers.Dense(64, activation='relu'))
#model.add(tf.keras.layers.Dropout(0.2))
#Capa de salida
model_pruebas.add(tf.keras.layers.Dense(10, activation='softmax'))
#Para entrenar el modelo
optimizador=tf.keras.optimizers.AdamW(learning_rate=0.0015, weight_decay=0.004)
model_pruebas.compile(optimizer=optimizador, loss='categorical_crossentropy', metrics=['accuracy']) #funcion de perdida
etiquetas_pruebas = tf.keras.utils.to_categorical(fullEtiquetas)
model_pruebas.fit(fullImagenes, etiquetas_pruebas, epochs=200, callbacks=[early_stopping, reduce_on_plateau], validation_split=0.2) #Se le añade el callback personalizado
# Out:
# Epoch 1/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.7629 - loss: 0.7430 - val_accuracy: 0.9631 - val_loss: 0.1156 - learning_rate: 0.0015
# Epoch 2/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9516 - loss: 0.1554 - val_accuracy: 0.9762 - val_loss: 0.0714 - learning_rate: 0.0015
# Epoch 3/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9610 - loss: 0.1249 - val_accuracy: 0.9803 - val_loss: 0.0605 - learning_rate: 0.0015
# Epoch 4/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9656 - loss: 0.1084 - val_accuracy: 0.9804 - val_loss: 0.0614 - learning_rate: 0.0015
# Epoch 5/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9681 - loss: 0.1028 - val_accuracy: 0.9814 - val_loss: 0.0572 - learning_rate: 0.0015
# Epoch 6/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9692 - loss: 0.0968 - val_accuracy: 0.9834 - val_loss: 0.0498 - learning_rate: 0.0015
# Epoch 7/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9717 - loss: 0.0917 - val_accuracy: 0.9856 - val_loss: 0.0441 - learning_rate: 0.0015
# Epoch 8/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9732 - loss: 0.0867 - val_accuracy: 0.9874 - val_loss: 0.0410 - learning_rate: 0.0015
# Epoch 9/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9730 - loss: 0.0858 - val_accuracy: 0.9876 - val_loss: 0.0392 - learning_rate: 0.0015
# Epoch 10/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9727 - loss: 0.0882 - val_accuracy: 0.9844 - val_loss: 0.0470 - learning_rate: 0.0015
# Epoch 11/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9742 - loss: 0.0802 - val_accuracy: 0.9874 - val_loss: 0.0395 - learning_rate: 0.0015
# Epoch 12/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9739 - loss: 0.0820 - val_accuracy: 0.9831 - val_loss: 0.0514 - learning_rate: 0.0015
# Epoch 13/200
# 2985/3000 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0752
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9767 - loss: 0.0752 - val_accuracy: 0.9849 - val_loss: 0.0451 - learning_rate: 0.0015
# Epoch 14/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9775 - loss: 0.0698 - val_accuracy: 0.9890 - val_loss: 0.0323 - learning_rate: 0.0011
# Epoch 15/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9779 - loss: 0.0690 - val_accuracy: 0.9887 - val_loss: 0.0360 - learning_rate: 0.0011
# Epoch 16/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9773 - loss: 0.0705 - val_accuracy: 0.9879 - val_loss: 0.0381 - learning_rate: 0.0011
# Epoch 17/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9788 - loss: 0.0678 - val_accuracy: 0.9893 - val_loss: 0.0315 - learning_rate: 0.0011
# Epoch 18/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9791 - loss: 0.0666 - val_accuracy: 0.9896 - val_loss: 0.0311 - learning_rate: 0.0011
# Epoch 19/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9797 - loss: 0.0665 - val_accuracy: 0.9898 - val_loss: 0.0324 - learning_rate: 0.0011
# Epoch 20/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9791 - loss: 0.0658 - val_accuracy: 0.9872 - val_loss: 0.0401 - learning_rate: 0.0011
# Epoch 21/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9796 - loss: 0.0647 - val_accuracy: 0.9868 - val_loss: 0.0407 - learning_rate: 0.0011
# Epoch 22/200
# 2979/3000 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0640
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9797 - loss: 0.0640 - val_accuracy: 0.9894 - val_loss: 0.0325 - learning_rate: 0.0011
# Epoch 23/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9820 - loss: 0.0590 - val_accuracy: 0.9907 - val_loss: 0.0297 - learning_rate: 8.4375e-04
# Epoch 24/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9811 - loss: 0.0602 - val_accuracy: 0.9909 - val_loss: 0.0289 - learning_rate: 8.4375e-04
# Epoch 25/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9812 - loss: 0.0585 - val_accuracy: 0.9909 - val_loss: 0.0289 - learning_rate: 8.4375e-04
# Epoch 26/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9819 - loss: 0.0568 - val_accuracy: 0.9911 - val_loss: 0.0287 - learning_rate: 8.4375e-04
# Epoch 27/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9822 - loss: 0.0568 - val_accuracy: 0.9909 - val_loss: 0.0282 - learning_rate: 8.4375e-04
# Epoch 28/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9824 - loss: 0.0563 - val_accuracy: 0.9913 - val_loss: 0.0263 - learning_rate: 8.4375e-04
# Epoch 29/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9817 - loss: 0.0583 - val_accuracy: 0.9911 - val_loss: 0.0268 - learning_rate: 8.4375e-04
# Epoch 30/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9823 - loss: 0.0563 - val_accuracy: 0.9920 - val_loss: 0.0243 - learning_rate: 8.4375e-04
# Epoch 31/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9820 - loss: 0.0557 - val_accuracy: 0.9920 - val_loss: 0.0247 - learning_rate: 8.4375e-04
# Epoch 32/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9816 - loss: 0.0563 - val_accuracy: 0.9918 - val_loss: 0.0255 - learning_rate: 8.4375e-04
# Epoch 33/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9830 - loss: 0.0536 - val_accuracy: 0.9914 - val_loss: 0.0274 - learning_rate: 8.4375e-04
# Epoch 34/200
# 2997/3000 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0535
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0006328124727588147.
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9832 - loss: 0.0535 - val_accuracy: 0.9914 - val_loss: 0.0278 - learning_rate: 8.4375e-04
# Epoch 35/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9838 - loss: 0.0513 - val_accuracy: 0.9908 - val_loss: 0.0277 - learning_rate: 6.3281e-04
# Epoch 36/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9830 - loss: 0.0538 - val_accuracy: 0.9917 - val_loss: 0.0254 - learning_rate: 6.3281e-04
# Epoch 37/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9836 - loss: 0.0517 - val_accuracy: 0.9922 - val_loss: 0.0228 - learning_rate: 6.3281e-04
# Epoch 38/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.9842 - loss: 0.0500 - val_accuracy: 0.9917 - val_loss: 0.0265 - learning_rate: 6.3281e-04
# Epoch 39/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9845 - loss: 0.0490 - val_accuracy: 0.9921 - val_loss: 0.0258 - learning_rate: 6.3281e-04
# Epoch 40/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9832 - loss: 0.0526 - val_accuracy: 0.9923 - val_loss: 0.0247 - learning_rate: 6.3281e-04
# Epoch 41/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9840 - loss: 0.0507
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00047460937639698386.
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9840 - loss: 0.0507 - val_accuracy: 0.9925 - val_loss: 0.0234 - learning_rate: 6.3281e-04
# Epoch 42/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - accuracy: 0.9841 - loss: 0.0483 - val_accuracy: 0.9925 - val_loss: 0.0238 - learning_rate: 4.7461e-04
# Epoch 43/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9852 - loss: 0.0482 - val_accuracy: 0.9927 - val_loss: 0.0232 - learning_rate: 4.7461e-04
# Epoch 44/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9848 - loss: 0.0470 - val_accuracy: 0.9929 - val_loss: 0.0236 - learning_rate: 4.7461e-04
# Epoch 45/200
# 2977/3000 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9848 - loss: 0.0498
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0003559570322977379.
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9848 - loss: 0.0498 - val_accuracy: 0.9928 - val_loss: 0.0230 - learning_rate: 4.7461e-04
# Epoch 46/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9842 - loss: 0.0484 - val_accuracy: 0.9933 - val_loss: 0.0213 - learning_rate: 3.5596e-04
# Epoch 47/200
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9848 - loss: 0.0463 - val_accuracy: 0.9927 - val_loss: 0.0239 - learning_rate: 3.5596e-04
# Epoch 48/200
# 2942/3000 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0439
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 30
#      28 model_pruebas.compile(optimizer=optimizador, loss='categorical_crossentropy', metrics=['accuracy']) #funcion de perdida
#      29 etiquetas_pruebas = tf.keras.utils.to_categorical(fullEtiquetas)
# ---> 30 model_pruebas.fit(fullImagenes, etiquetas_pruebas, epochs=200, callbacks=[early_stopping, reduce_on_plateau], validation_split=0.2) #Se le añade el callback personalizado
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Redes-Neuronales/tf/lib64/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:137, in call_function(args, kwargs, tracing_options)
#     132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
# --> 137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
#     139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/lib64/python3.12/inspect.py:3273, in Signature.bind(self, *args, **kwargs)
#    3268 def bind(self, /, *args, **kwargs):
#    3269     """Get a BoundArguments object, that maps the passed `args`
#    3270     and `kwargs` to the function's signature.  Raises `TypeError`
#    3271     if the passed arguments can not be bound.
#    3272     """
# -> 3273     return self._bind(args, kwargs)
#
# File /usr/lib64/python3.12/inspect.py:3266, in Signature._bind(self, args, kwargs, partial)
#    3261     else:
#    3262         raise TypeError(
#    3263             'got an unexpected keyword argument {arg!r}'.format(
#    3264                 arg=next(iter(kwargs))))
# -> 3266 return self._bound_arguments_cls(self, arguments)
#
# File /usr/lib64/python3.12/inspect.py:2884, in BoundArguments.__init__(self, signature, arguments)
#    2866 """Result of `Signature.bind` call.  Holds the mapping of arguments
#    2867 to the function's parameters.
#    2868
#    (...)
#    2879     Dict of keyword arguments values.
#    2880 """
#    2882 __slots__ = ('arguments', '_signature', '__weakref__')
# -> 2884 def __init__(self, signature, arguments):
#    2885     self.arguments = arguments
#    2886     self._signature = signature
#
# KeyboardInterrupt:

# %%
preds_train_pruebas = model_pruebas.predict(fullImagenes).argmax(axis=1)
acc_train = accuracy_score(etiquetas_pruebas.argmax(axis=1), preds_train_pruebas)
print("----------------------ENTRENAMIENTO---------------------------------")
print("Precisión: ", acc_train, "Tasa de error: ", 1 - acc_train)
preds_test_pruebas = model_definitivo.predict(images_test).argmax(axis=1)
acc_test = accuracy_score(etiquetas_test, preds_test_pruebas)
print("----------------------PRUEBA---------------------------------")
print("Precisión: ", acc_test, "Tasa de error: ", 1 - acc_test)
# Out:
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
# ----------------------ENTRENAMIENTO---------------------------------
# Precisión:  0.993375 Tasa de error:  0.006624999999999992
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ----------------------PRUEBA---------------------------------
# Precisión:  0.9943 Tasa de error:  0.005700000000000038
